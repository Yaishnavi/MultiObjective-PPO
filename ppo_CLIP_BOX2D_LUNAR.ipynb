# %%
import torch
import torch.nn as nn
from torch.distributions import Categorical
import gym, os
from itertools import count
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import pdb

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Model(nn.Module):
    def __init__(self, state_dim, action_dim, n_latent_var):
        super(Model, self).__init__()
        self.affine = nn.Linear(state_dim, n_latent_var)
        
        # actor
        self.action_layer = nn.Sequential(
                nn.Linear(state_dim, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, action_dim),
                nn.Softmax(dim = -1)
                )
        
        # critic
        self.value_layer = nn.Sequential(
                nn.Linear(state_dim, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, 1)
                )
        
        # Memory:
        self.actions = []
        self.states = []
        self.logprobs = []
        self.state_values = []
        self.rewards = []
        
    def forward(self, state, action=None, evaluate=False):
        # if evaluate is True then we also need to pass an action for evaluation
        # else we return a new action from distribution
        if not evaluate:
            state = torch.from_numpy(state).float().to(device)
        
        state_value = self.value_layer(state)
        
        action_probs = self.action_layer(state)
        action_distribution = Categorical(action_probs)
        
        if not evaluate:
            action = action_distribution.sample()
            self.actions.append(action)
            
        self.logprobs.append(action_distribution.log_prob(action))
        self.state_values.append(state_value)
        
        if evaluate:
            return action_distribution.entropy().mean()
        
        if not evaluate:
            return action.item()
        
    def clearMemory(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.state_values[:]
        del self.rewards[:]

# %%
class PPO:
    def __init__(self, state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip):
        self.lr = lr
        self.betas = betas
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.policy = Model(state_dim, action_dim, n_latent_var).to(device)
        self.optimizer = torch.optim.Adam(self.policy.parameters(),
                                              lr=lr, betas=betas)
        self.policy_old = Model(state_dim, action_dim, n_latent_var).to(device)
        
        self.MseLoss = nn.MSELoss()
        
    def update(self):   
        # Monte Carlo estimate of state rewards:
        rewards = []
        discounted_reward = 0
        for reward in reversed(self.policy_old.rewards):
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
        
        # Normalizing the rewards:
        rewards = torch.tensor(rewards).to(device)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-5)
        
        # convert list in tensor
        old_states = torch.tensor(self.policy_old.states).to(device).detach()
        old_actions = torch.tensor(self.policy_old.actions).to(device).detach()
        old_logprobs = torch.tensor(self.policy_old.logprobs).to(device).detach()
        

        # Optimize policy for K epochs:
        for _ in range(self.K_epochs):
            # Evaluating old actions and values :
            dist_entropy = self.policy(old_states, old_actions, evaluate=True)
            # Finding the ratio (pi_theta / pi_theta__old):
            logprobs = self.policy.logprobs[0].to(device)
            ratios = torch.exp(logprobs - old_logprobs.detach())
            

            # Finding Surrogate Loss:
            state_values = self.policy.state_values[0].to(device)
            advantages = rewards - state_values.squeeze().detach()
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy
            
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
            self.policy.clearMemory()
            
        self.policy_old.clearMemory()
        
        # Copy new weights into old policy:
        self.policy_old.load_state_dict(self.policy.state_dict())

# %%
############# Hyperparameters ##############
env_name = "LunarLander-v2"
# creating environment
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = 4

n_episodes = 400
max_timesteps = 300
log_interval = 10
n_latent_var = 64           # number of variables in hidden layer
lr = 0.0007
betas = (0.9, 0.999)
gamma = 0.99                # discount factor
K_epochs = 4                # update policy for K epochs
eps_clip = 0.2              # clip parameter for PPO
random_seed = None
#############################################
if random_seed:
    torch.manual_seed(random_seed)
    env.seed(random_seed)

filename = "PPO_{}.pth".format(env_name)
directory = "./preTrained/"

# %%
ppo = PPO(state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip)

running_reward = 0
rewards = []
for ep in range(1, n_episodes+1):
    state = env.reset()
    for t in range(max_timesteps):
        # Running policy_old:
        action = ppo.policy_old(state)
        state_n, reward, done, _ = env.step(action)
        # Saving state and reward:
        ppo.policy_old.states.append(state)
        ppo.policy_old.rewards.append(reward)
        state = state_n

        running_reward +=reward 
        if done:
            # save model
            torch.save(ppo.policy.state_dict(), directory+filename)
            rewards.append(running_reward)
            break
    
    
    print('Episode: {}\tReward: {}'.format(ep, int(running_reward)))
    running_reward = 0
    env.close()
plt.plot(np.arange(len(rewards)), rewards)

plt.ylabel('Total Reward')
plt.xlabel('Episode')
plt.savefig('lunar',bbox_inches='tight',facecolor="#FFFFFF")
plt.show()
# Out:
# Episode: 1	Reward: -71
# Episode: 2	Reward: -261
# Episode: 3	Reward: -147
# Episode: 4	Reward: -96
# Episode: 5	Reward: -331
# Episode: 6	Reward: -152
# Episode: 7	Reward: -281
# Episode: 8	Reward: -82
# Episode: 9	Reward: -140
# Episode: 10	Reward: -94
# Episode: 11	Reward: -75
# Episode: 12	Reward: -405
# Episode: 13	Reward: -114
# Episode: 14	Reward: -270
# Episode: 15	Reward: -85
# Episode: 16	Reward: -121
# Episode: 17	Reward: -68
# Episode: 18	Reward: -297
# Episode: 19	Reward: -100
# Episode: 20	Reward: -540
# Episode: 21	Reward: -111
# Episode: 22	Reward: -265
# Episode: 23	Reward: -341
# Episode: 24	Reward: -122
# Episode: 25	Reward: -279
# Episode: 26	Reward: -249
# Episode: 27	Reward: -261
# Episode: 28	Reward: -258
# Episode: 29	Reward: -354
# Episode: 30	Reward: -388
# Episode: 31	Reward: -94
# Episode: 32	Reward: -185
# Episode: 33	Reward: -219
# Episode: 34	Reward: -255
# Episode: 35	Reward: -116
# Episode: 36	Reward: -185
# Episode: 37	Reward: -183
# Episode: 38	Reward: -85
# Episode: 39	Reward: -113
# Episode: 40	Reward: -25
# Episode: 41	Reward: -291
# Episode: 42	Reward: -497
# Episode: 43	Reward: -74
# Episode: 44	Reward: -102
# Episode: 45	Reward: -174
# Episode: 46	Reward: -314
# Episode: 47	Reward: -120
# Episode: 48	Reward: -51
# Episode: 49	Reward: -76
# Episode: 50	Reward: -139
# Episode: 51	Reward: -54
# Episode: 52	Reward: -221
# Episode: 53	Reward: -45
# Episode: 54	Reward: -23
# Episode: 55	Reward: -98
# Episode: 56	Reward: -107
# Episode: 57	Reward: -167
# Episode: 58	Reward: -180
# Episode: 59	Reward: -202
# Episode: 60	Reward: -303
# Episode: 61	Reward: -18
# Episode: 62	Reward: -208
# Episode: 63	Reward: -117
# Episode: 64	Reward: -96
# Episode: 65	Reward: -98
# Episode: 66	Reward: -143
# Episode: 67	Reward: -334
# Episode: 68	Reward: -122
# Episode: 69	Reward: -144
# Episode: 70	Reward: -85
# Episode: 71	Reward: -102
# Episode: 72	Reward: -199
# Episode: 73	Reward: -102
# Episode: 74	Reward: -341
# Episode: 75	Reward: -61
# Episode: 76	Reward: -324
# Episode: 77	Reward: -170
# Episode: 78	Reward: -72
# Episode: 79	Reward: -58
# Episode: 80	Reward: -183
# Episode: 81	Reward: -226
# Episode: 82	Reward: -253
# Episode: 83	Reward: -97
# Episode: 84	Reward: -267
# Episode: 85	Reward: -319
# Episode: 86	Reward: -31
# Episode: 87	Reward: -389
# Episode: 88	Reward: -176
# Episode: 89	Reward: -219
# Episode: 90	Reward: -105
# Episode: 91	Reward: -130
# Episode: 92	Reward: -318
# Episode: 93	Reward: -157
# Episode: 94	Reward: -105
# Episode: 95	Reward: -143
# Episode: 96	Reward: -65
# Episode: 97	Reward: -457
# Episode: 98	Reward: -369
# Episode: 99	Reward: -79
# Episode: 100	Reward: -124
# Episode: 101	Reward: -98
# Episode: 102	Reward: -100
# Episode: 103	Reward: -115
# Episode: 104	Reward: -13
# Episode: 105	Reward: -126
# Episode: 106	Reward: -105
# Episode: 107	Reward: -114
# Episode: 108	Reward: -317
# Episode: 109	Reward: -158
# Episode: 110	Reward: -88
# Episode: 111	Reward: -55
# Episode: 112	Reward: 12
# Episode: 113	Reward: -247
# Episode: 114	Reward: -148
# Episode: 115	Reward: -117
# Episode: 116	Reward: -67
# Episode: 117	Reward: -168
# Episode: 118	Reward: -348
# Episode: 119	Reward: -289
# Episode: 120	Reward: -236
# Episode: 121	Reward: -22
# Episode: 122	Reward: -99
# Episode: 123	Reward: -169
# Episode: 124	Reward: -155
# Episode: 125	Reward: -262
# Episode: 126	Reward: -33
# Episode: 127	Reward: -54
# Episode: 128	Reward: -94
# Episode: 129	Reward: -118
# Episode: 130	Reward: -310
# Episode: 131	Reward: -305
# Episode: 132	Reward: -102
# Episode: 133	Reward: -119
# Episode: 134	Reward: -424
# Episode: 135	Reward: -99
# Episode: 136	Reward: -86
# Episode: 137	Reward: -106
# Episode: 138	Reward: -271
# Episode: 139	Reward: -64
# Episode: 140	Reward: -157
# Episode: 141	Reward: -223
# Episode: 142	Reward: -86
# Episode: 143	Reward: -107
# Episode: 144	Reward: -181
# Episode: 145	Reward: -249
# Episode: 146	Reward: -158
# Episode: 147	Reward: -273
# Episode: 148	Reward: -103
# Episode: 149	Reward: -71
# Episode: 150	Reward: -137
# Episode: 151	Reward: -121
# Episode: 152	Reward: -213
# Episode: 153	Reward: -117
# Episode: 154	Reward: -222
# Episode: 155	Reward: -508
# Episode: 156	Reward: -98
# Episode: 157	Reward: -237
# Episode: 158	Reward: -254
# Episode: 159	Reward: -304
# Episode: 160	Reward: -466
# Episode: 161	Reward: -79
# Episode: 162	Reward: -98
# Episode: 163	Reward: -117
# Episode: 164	Reward: -1
# Episode: 165	Reward: -169
# Episode: 166	Reward: -343
# Episode: 167	Reward: -210
# Episode: 168	Reward: -316
# Episode: 169	Reward: 122
# Episode: 170	Reward: -121
# Episode: 171	Reward: -121
# Episode: 172	Reward: -108
# Episode: 173	Reward: -156
# Episode: 174	Reward: -376
# Episode: 175	Reward: -174
# Episode: 176	Reward: -77
# Episode: 177	Reward: -116
# Episode: 178	Reward: -100
# Episode: 179	Reward: -301
# Episode: 180	Reward: -354
# Episode: 181	Reward: -199
# Episode: 182	Reward: -148
# Episode: 183	Reward: -72
# Episode: 184	Reward: -121
# Episode: 185	Reward: -209
# Episode: 186	Reward: -289
# Episode: 187	Reward: -117
# Episode: 188	Reward: -147
# Episode: 189	Reward: -103
# Episode: 190	Reward: -93
# Episode: 191	Reward: -104
# Episode: 192	Reward: -223
# Episode: 193	Reward: -64
# Episode: 194	Reward: -130
# Episode: 195	Reward: -114
# Episode: 196	Reward: -174
# Episode: 197	Reward: -343
# Episode: 198	Reward: -104
# Episode: 199	Reward: -127
# Episode: 200	Reward: -156
# Episode: 201	Reward: -321
# Episode: 202	Reward: -334
# Episode: 203	Reward: -508
# Episode: 204	Reward: -227
# Episode: 205	Reward: -141
# Episode: 206	Reward: -239
# Episode: 207	Reward: -195
# Episode: 208	Reward: -123
# Episode: 209	Reward: -106
# Episode: 210	Reward: -263
# Episode: 211	Reward: -284
# Episode: 212	Reward: -118
# Episode: 213	Reward: -99
# Episode: 214	Reward: -203
# Episode: 215	Reward: -125
# Episode: 216	Reward: -101
# Episode: 217	Reward: -93
# Episode: 218	Reward: -220
# Episode: 219	Reward: -111
# Episode: 220	Reward: -170
# Episode: 221	Reward: -119
# Episode: 222	Reward: -137
# Episode: 223	Reward: -239
# Episode: 224	Reward: -140
# Episode: 225	Reward: -293
# Episode: 226	Reward: -171
# Episode: 227	Reward: -60
# Episode: 228	Reward: -204
# Episode: 229	Reward: -175
# Episode: 230	Reward: -104
# Episode: 231	Reward: -90
# Episode: 232	Reward: -109
# Episode: 233	Reward: -139
# Episode: 234	Reward: -79
# Episode: 235	Reward: -154
# Episode: 236	Reward: -321
# Episode: 237	Reward: -79
# Episode: 238	Reward: -113
# Episode: 239	Reward: -183
# Episode: 240	Reward: -147
# Episode: 241	Reward: -41
# Episode: 242	Reward: -221
# Episode: 243	Reward: -267
# Episode: 244	Reward: -430
# Episode: 245	Reward: -36
# Episode: 246	Reward: -160
# Episode: 247	Reward: -90
# Episode: 248	Reward: -270
# Episode: 249	Reward: -293
# Episode: 250	Reward: -196
# Episode: 251	Reward: -127
# Episode: 252	Reward: -115
# Episode: 253	Reward: -112
# Episode: 254	Reward: -277
# Episode: 255	Reward: -330
# Episode: 256	Reward: -101
# Episode: 257	Reward: -396
# Episode: 258	Reward: -125
# Episode: 259	Reward: -144
# Episode: 260	Reward: -277
# Episode: 261	Reward: -105
# Episode: 262	Reward: -170
# Episode: 263	Reward: -144
# Episode: 264	Reward: -94
# Episode: 265	Reward: -77
# Episode: 266	Reward: -254
# Episode: 267	Reward: -107
# Episode: 268	Reward: -40
# Episode: 269	Reward: -269
# Episode: 270	Reward: -190
# Episode: 271	Reward: -173
# Episode: 272	Reward: -111
# Episode: 273	Reward: -397
# Episode: 274	Reward: -126
# Episode: 275	Reward: -103
# Episode: 276	Reward: -104
# Episode: 277	Reward: -116
# Episode: 278	Reward: -142
# Episode: 279	Reward: -249
# Episode: 280	Reward: -455
# Episode: 281	Reward: -100
# Episode: 282	Reward: -105
# Episode: 283	Reward: -122
# Episode: 284	Reward: -181
# Episode: 285	Reward: -316
# Episode: 286	Reward: -100
# Episode: 287	Reward: -86
# Episode: 288	Reward: -111
# Episode: 289	Reward: -134
# Episode: 290	Reward: -152
# Episode: 291	Reward: -190
# Episode: 292	Reward: -205
# Episode: 293	Reward: -115
# Episode: 294	Reward: -80
# Episode: 295	Reward: -143
# Episode: 296	Reward: -126
# Episode: 297	Reward: -47
# Episode: 298	Reward: -229
# Episode: 299	Reward: -70
# Episode: 300	Reward: -90
# Episode: 301	Reward: -116
# Episode: 302	Reward: -81
# Episode: 303	Reward: -262
# Episode: 304	Reward: -182
# Episode: 305	Reward: -198
# Episode: 306	Reward: -135
# Episode: 307	Reward: -426
# Episode: 308	Reward: -165
# Episode: 309	Reward: -312
# Episode: 310	Reward: -51
# Episode: 311	Reward: -115
# Episode: 312	Reward: -117
# Episode: 313	Reward: -350
# Episode: 314	Reward: -240
# Episode: 315	Reward: -237
# Episode: 316	Reward: -337
# Episode: 317	Reward: -104
# Episode: 318	Reward: -237
# Episode: 319	Reward: -164
# Episode: 320	Reward: -71
# Episode: 321	Reward: -166
# Episode: 322	Reward: -92
# Episode: 323	Reward: -114
# Episode: 324	Reward: -77
# Episode: 325	Reward: -125
# Episode: 326	Reward: -80
# Episode: 327	Reward: -98
# Episode: 328	Reward: -107
# Episode: 329	Reward: -84
# Episode: 330	Reward: 22
# Episode: 331	Reward: -236
# Episode: 332	Reward: -71
# Episode: 333	Reward: -101
# Episode: 334	Reward: -294
# Episode: 335	Reward: -130
# Episode: 336	Reward: -109
# Episode: 337	Reward: -297
# Episode: 338	Reward: -146
# Episode: 339	Reward: -153
# Episode: 340	Reward: -250
# Episode: 341	Reward: -110
# Episode: 342	Reward: -153
# Episode: 343	Reward: -192
# Episode: 344	Reward: -199
# Episode: 345	Reward: -108
# Episode: 346	Reward: -105
# Episode: 347	Reward: -58
# Episode: 348	Reward: -112
# Episode: 349	Reward: -130
# Episode: 350	Reward: -243
# Episode: 351	Reward: -300
# Episode: 352	Reward: -111
# Episode: 353	Reward: -112
# Episode: 354	Reward: -94
# Episode: 355	Reward: -108
# Episode: 356	Reward: -118
# Episode: 357	Reward: -286
# Episode: 358	Reward: -23
# Episode: 359	Reward: -169
# Episode: 360	Reward: -134
# Episode: 361	Reward: -151
# Episode: 362	Reward: -136
# Episode: 363	Reward: -159
# Episode: 364	Reward: -473
# Episode: 365	Reward: -388
# Episode: 366	Reward: -137
# Episode: 367	Reward: -100
# Episode: 368	Reward: -106
# Episode: 369	Reward: -187
# Episode: 370	Reward: -125
# Episode: 371	Reward: -232
# Episode: 372	Reward: -14
# Episode: 373	Reward: -268
# Episode: 374	Reward: -179
# Episode: 375	Reward: -130
# Episode: 376	Reward: -260
# Episode: 377	Reward: -96
# Episode: 378	Reward: -108
# Episode: 379	Reward: -120
# Episode: 380	Reward: -236
# Episode: 381	Reward: -106
# Episode: 382	Reward: -68
# Episode: 383	Reward: -280
# Episode: 384	Reward: -109
# Episode: 385	Reward: -396
# Episode: 386	Reward: -434
# Episode: 387	Reward: -143
# Episode: 388	Reward: -223
# Episode: 389	Reward: -98
# Episode: 390	Reward: -426
# Episode: 391	Reward: -263
# Episode: 392	Reward: -64
# Episode: 393	Reward: 11
# Episode: 394	Reward: -127
# Episode: 395	Reward: -129
# Episode: 396	Reward: -74
# Episode: 397	Reward: -87
# Episode: 398	Reward: -23
# Episode: 399	Reward: -80
# Episode: 400	Reward: -134
