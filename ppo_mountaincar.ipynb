# %%
import torch
import torch.nn as nn
from torch.distributions import Categorical
import gym, os
from itertools import count
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
from math import log2
import pdb

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Model(nn.Module):
    def __init__(self, state_dim, action_dim, n_latent_var):
        super(Model, self).__init__()
        self.affine = nn.Linear(state_dim, n_latent_var)
        
        # actor
        self.action_layer = nn.Sequential(
                nn.Linear(state_dim, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, action_dim),
                nn.Softmax(dim = -1)
                )
        
        # critic
        self.value_layer = nn.Sequential(
                nn.Linear(state_dim, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, 1)
                )
        
        # Memory:
        self.actions = []
        self.states = []
        self.logprobs = []
        self.state_values = []
        self.rewards = []
        
    def forward(self, state, action=None, evaluate=False):
        # if evaluate is True then we also need to pass an action for evaluation
        # else we return a new action from distribution
        if not evaluate:
            state = torch.from_numpy(state).float().to(device)
        
        state_value = self.value_layer(state)
        
        action_probs = self.action_layer(state)
        action_distribution = Categorical(action_probs)
        
        if not evaluate:
            action = action_distribution.sample()
            self.actions.append(action)
            
        self.logprobs.append(action_distribution.log_prob(action))
        self.state_values.append(state_value)
        
        if evaluate:
            return action_distribution.entropy().mean()
        
        if not evaluate:
            return action.item()
        
    def clearMemory(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.state_values[:]
        del self.rewards[:]

# %%
class PPO:
    def __init__(self, state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip):
        self.lr = lr
        self.betas = betas
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.policy = Model(state_dim, action_dim, n_latent_var).to(device)
        self.optimizer = torch.optim.Adam(self.policy.parameters(),
                                              lr=lr, betas=betas)
        self.policy_old = Model(state_dim, action_dim, n_latent_var).to(device)
        
        self.MseLoss = nn.MSELoss()
        self.kl = 0

    def update(self):   
        # Monte Carlo estimate of state rewards:
        rewards = []
        discounted_reward = 0
        for reward in reversed(self.policy_old.rewards):
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
        
        # Normalizing the rewards:
        rewards = torch.tensor(rewards).to(device)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-5)
        
        # convert list in tensor
        old_states = torch.tensor(self.policy_old.states).to(device).detach()
        old_actions = torch.tensor(self.policy_old.actions).to(device).detach()
        old_logprobs = torch.tensor(self.policy_old.logprobs).to(device).detach()
        
        # Optimize policy for K epochs:
        for _ in range(self.K_epochs):
            # Evaluating old actions and values :
            dist_entropy = self.policy(old_states, old_actions, evaluate=True)
            # Finding the ratio (pi_theta / pi_theta__old):
            logprobs = self.policy.logprobs[0].to(device)
            ratios = torch.exp(logprobs - old_logprobs.detach())
            self.kl =F.kl_div(logprobs - old_logprobs.detach())

            # Finding Surrogate Loss:
            state_values = self.policy.state_values[0].to(device)
            advantages = rewards - state_values.squeeze().detach()
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
            self.policy.clearMemory()
            
        self.policy_old.clearMemory()
        
        # Copy new weights into old policy:
        self.policy_old.load_state_dict(self.policy.state_dict())

# %%
class PPO:
    def __init__(self, state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip):
        self.lr = lr
        self.betas = betas
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.policy = Model(state_dim, action_dim, n_latent_var).to(device)
        self.optimizer = torch.optim.Adam(self.policy.parameters(),
                                              lr=lr, betas=betas)
        self.policy_old = Model(state_dim, action_dim, n_latent_var).to(device)
        
        self.MseLoss = nn.MSELoss()
        self.kl = 0

    def update(self):   
        # Monte Carlo estimate of state rewards:
        rewards = []
        discounted_reward = 0
        for reward in reversed(self.policy_old.rewards):
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
        
        # Normalizing the rewards:
        rewards = torch.tensor(rewards).to(device)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-5)
        
        # convert list in tensor
        old_states = torch.tensor(self.policy_old.states).to(device).detach()
        old_actions = torch.tensor(self.policy_old.actions).to(device).detach()
        old_logprobs = torch.tensor(self.policy_old.logprobs).to(device).detach()
        
        # Optimize policy for K epochs:
        for _ in range(self.K_epochs):
            # Evaluating old actions and values :
            dist_entropy = self.policy(old_states, old_actions, evaluate=True)
            # Finding the ratio (pi_theta / pi_theta__old):
            logprobs = self.policy.logprobs[0].to(device)
            ratios = torch.exp(logprobs - old_logprobs.detach())
            self.kl =F.kl_div(logprobs - old_logprobs.detach())

            # Finding Surrogate Loss:
            state_values = self.policy.state_values[0].to(device)
            advantages = rewards - state_values.squeeze().detach()
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
            self.policy.clearMemory()
            
        self.policy_old.clearMemory()
        
        # Copy new weights into old policy:
        self.policy_old.load_state_dict(self.policy.state_dict())

# %%
import fruit.envs.games.mountain_car.engine as mc
from fruit.envs.juice import FruitEnvironment

game = mc.MountainCar(graphical_state=False, frame_skip=1, render=False, speed=1000, is_debug=False)
env = FruitEnvironment(game)
print(env.get_number_of_objectives())
print(env.get_number_of_agents())
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# #################################################
# Game environment MOUNTAIN CAR is created !!!
# Seed: 146
# #################################################
# 3
# 1

# %%
state_dim = 1
action_dim = 3
n_obj = env.get_number_of_objectives()
n_episodes = 1000
max_timesteps = 5000
kl_param = 0.1
log_interval = 10
n_latent_var = 64           # number of variables in hidden layer
lr = 0.0007
betas = (0.9, 0.999)
gamma = 0.99                # discount factor
K_epochs = 4                # update policy for K epochs
eps_clip = 0.2              # clip parameter for PPO
random_seed = None
if random_seed:
    torch.manual_seed(random_seed)
    env.seed(random_seed)

filename = "PPO_MountainCar.pth"
directory = "./preTrained/"

# %%
ppo = PPO(state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip)

running_reward = 0
rewards = np.zeros((n_episodes,n_obj))
for ep in range(1, n_episodes+1):
    state = np.array([0.0])
    for t in range(max_timesteps):
        # Running policy_old:
        action = ppo.policy_old(state)
        reward = env.step(action)[0]
        state_n = env.get_state()
        done = env.is_terminal()
        # Saving state and reward:
        ppo.policy_old.states.append(state)
        ppo.policy_old.rewards.append(reward)
        state =  np.array([state_n])
        running_reward +=reward 
        if done:
            # save model
            torch.save(ppo.policy.state_dict(), directory+filename+str(0))
            rewards[ep-1,0]= running_reward
            break
        running_reward = 0

    for k in range(1,n_obj):
        state = np.array([0.0])
        for t in range(max_timesteps):
            # Running policy_old:
            action = ppo.policy_old(state)
            reward = env.step(action)[k]
            state_n = env.get_state()
            done = env.is_terminal()
            kl = ppo.kl
            new_reward = reward + (kl_param*kl)

            # Saving state and reward:
            ppo.policy_old.states.append(state)
            ppo.policy_old.rewards.append(new_reward)
            state = np.array([state_n])
            running_reward += new_reward 
            if done:
                # save model
                torch.save(ppo.policy.state_dict(), directory+filename+str(k))
                rewards[ep-1,k]= running_reward
                break

    print('Episode: {}\tReward: {}'.format(ep, rewards[ep-1,:]))
    running_reward = 0

plt.plot(np.arange(len(rewards[:,0])), rewards[:,0], label = 'reward1')
plt.plot(np.arange(len(rewards[:,1])), rewards[:,1], label = 'reward2')
plt.plot(np.arange(len(rewards[:,2])), rewards[:,2], label = 'reward3')
plt.ylabel('Total Reward')
plt.xlabel('Episode')
plt.savefig('mountaincar',bbox_inches='tight',facecolor="#FFFFFF")
plt.show()
# Out:
# [-1. -2. -2.]
# Episode: 430	Reward: [-1. -1. -1.]
# Episode: 431	Reward: [-1. -2. -3.]
# Episode: 432	Reward: [-1. -1. -1.]
# Episode: 433	Reward: [-1. -1. -1.]
# Episode: 434	Reward: [-1. -1. -1.]
# Episode: 435	Reward: [-1. -2. -2.]
# Episode: 436	Reward: [-1. -1. -1.]
# Episode: 437	Reward: [-1. -1. -1.]
# Episode: 438	Reward: [-1. -1. -1.]
# Episode: 439	Reward: [-1. -1. -1.]
# Episode: 440	Reward: [-1. -2. -3.]
# Episode: 441	Reward: [-1. -1. -1.]
# Episode: 442	Reward: [-1. -2. -2.]
# Episode: 443	Reward: [-1. -1. -2.]
# Episode: 444	Reward: [-1. -1. -1.]
# Episode: 445	Reward: [-1. -1. -1.]
# Episode: 446	Reward: [-1. -1. -2.]
# Episode: 447	Reward: [-1. -1. -1.]
# Episode: 448	Reward: [-1. -2. -2.]
# Episode: 449	Reward: [-1. -1. -2.]
# Episode: 450	Reward: [-1. -1. -1.]
# Episode: 451	Reward: [-1. -1. -2.]
# Episode: 452	Reward: [-1. -1. -1.]
# Episode: 453	Reward: [-1. -1. -1.]
# Episode: 454	Reward: [-1. -1. -2.]
# Episode: 455	Reward: [-1. -1. -2.]
# Episode: 456	Reward: [-1. -1. -1.]
# Episode: 457	Reward: [-1. -1. -1.]
# Episode: 458	Reward: [-1. -2. -2.]
# Episode: 459	Reward: [-1. -1. -2.]
# Episode: 460	Reward: [-1. -1. -1.]
# Episode: 461	Reward: [-1. -1. -1.]
# Episode: 462	Reward: [-1. -1. -1.]
# Episode: 463	Reward: [-1. -1. -1.]
# Episode: 464	Reward: [-1. -1. -1.]
# Episode: 465	Reward: [-1. -1. -1.]
# Episode: 466	Reward: [-1. -1. -1.]
# Episode: 467	Reward: [-1. -1. -1.]
# Episode: 468	Reward: [-1. -1. -1.]
# Episode: 469	Reward: [-1. -1. -1.]
# Episode: 470	Reward: [-1. -2. -2.]
# Episode: 471	Reward: [-1. -1. -1.]
# Episode: 472	Reward: [-1. -1. -2.]
# Episode: 473	Reward: [-1. -1. -1.]
# Episode: 474	Reward: [-1. -1. -1.]
# Episode: 475	Reward: [-1. -2. -2.]
# Episode: 476	Reward: [-1. -2. -2.]
# Episode: 477	Reward: [-1. -2. -3.]
# Episode: 478	Reward: [-1. -1. -1.]
# Episode: 479	Reward: [-1. -1. -1.]
# Episode: 480	Reward: [-1. -1. -1.]
# Episode: 481	Reward: [-1. -1. -2.]
# Episode: 482	Reward: [-1. -1. -2.]
# Episode: 483	Reward: [-1. -1. -1.]
# Episode: 484	Reward: [-1. -1. -2.]
# Episode: 485	Reward: [-1. -2. -2.]
# Episode: 486	Reward: [-1. -1. -1.]
# Episode: 487	Reward: [-1. -2. -2.]
# Episode: 488	Reward: [-1. -1. -2.]
# Episode: 489	Reward: [-1. -1. -2.]
# Episode: 490	Reward: [-1. -1. -2.]
# Episode: 491	Reward: [-1. -1. -1.]
# Episode: 492	Reward: [-1. -1. -1.]
# Episode: 493	Reward: [-1. -1. -1.]
# Episode: 494	Reward: [-1. -2. -2.]
# Episode: 495	Reward: [-1. -2. -2.]
# Episode: 496	Reward: [-1. -2. -2.]
# Episode: 497	Reward: [-1. -1. -1.]
# Episode: 498	Reward: [-1. -1. -1.]
# Episode: 499	Reward: [-1. -2. -2.]
# Episode: 500	Reward: [-1. -1. -1.]
# Episode: 501	Reward: [-1. -2. -2.]
# Episode: 502	Reward: [-1. -1. -1.]
# Episode: 503	Reward: [-1. -1. -1.]
# Episode: 504	Reward: [-1. -2. -2.]
# Episode: 505	Reward: [-1. -1. -1.]
# Episode: 506	Reward: [-1. -1. -1.]
# Episode: 507	Reward: [-1. -1. -1.]
# Episode: 508	Reward: [-1. -2. -2.]
# Episode: 509	Reward: [-1. -1. -1.]
# Episode: 510	Reward: [-1. -1. -1.]
# Episode: 511	Reward: [-1. -1. -1.]
# Episode: 512	Reward: [-1. -2. -2.]
# Episode: 513	Reward: [-1. -2. -2.]
# Episode: 514	Reward: [-1. -2. -2.]
# Episode: 515	Reward: [-1. -1. -1.]
# Episode: 516	Reward: [-1. -2. -2.]
# Episode: 517	Reward: [-1. -1. -1.]
# Episode: 518	Reward: [-1. -2. -3.]
# Episode: 519	Reward: [-1. -2. -3.]
# Episode: 520	Reward: [-1. -1. -2.]
# Episode: 521	Reward: [-1. -2. -2.]
# Episode: 522	Reward: [-1. -2. -3.]
# Episode: 523	Reward: [-1. -1. -2.]
# Episode: 524	Reward: [-1. -1. -1.]
# Episode: 525	Reward: [-1. -1. -1.]
# Episode: 526	Reward: [-1. -2. -2.]
# Episode: 527	Reward: [-1. -2. -2.]
# Episode: 528	Reward: [-1. -2. -2.]
# Episode: 529	Reward: [-1. -1. -1.]
# Episode: 530	Reward: [-1. -1. -1.]
# Episode: 531	Reward: [-1. -2. -3.]
# Episode: 532	Reward: [-1. -1. -2.]
# Episode: 533	Reward: [-1. -1. -2.]
# Episode: 534	Reward: [-1. -2. -3.]
# Episode: 535	Reward: [-1. -2. -2.]
# Episode: 536	Reward: [-1. -1. -2.]
# Episode: 537	Reward: [-1. -2. -3.]
# Episode: 538	Reward: [-1. -1. -1.]
# Episode: 539	Reward: [-1. -2. -2.]
# Episode: 540	Reward: [-1. -1. -2.]
# Episode: 541	Reward: [-1. -1. -2.]
# Episode: 542	Reward: [-1. -1. -1.]
# Episode: 543	Reward: [-1. -2. -2.]
# Episode: 544	Reward: [-1. -1. -1.]
# Episode: 545	Reward: [-1. -1. -1.]
# Episode: 546	Reward: [-1. -1. -2.]
# Episode: 547	Reward: [-1. -1. -1.]
# Episode: 548	Reward: [-1. -2. -2.]
# Episode: 549	Reward: [-1. -1. -1.]
# Episode: 550	Reward: [-1. -1. -2.]
# Episode: 551	Reward: [-1. -1. -1.]
# Episode: 552	Reward: [-1. -1. -2.]
# Episode: 553	Reward: [-1. -2. -3.]
# Episode: 554	Reward: [-1. -2. -3.]
# Episode: 555	Reward: [-1. -1. -1.]
# Episode: 556	Reward: [-1. -1. -1.]
# Episode: 557	Reward: [-1. -1. -1.]
# Episode: 558	Reward: [-1. -1. -1.]
# Episode: 559	Reward: [-1. -2. -2.]
# Episode: 560	Reward: [-1. -1. -2.]
# Episode: 561	Reward: [-1. -1. -1.]
# Episode: 562	Reward: [-1. -2. -2.]
# Episode: 563	Reward: [-1. -1. -1.]
# Episode: 564	Reward: [-1. -1. -1.]
# Episode: 565	Reward: [-1. -1. -1.]
# Episode: 566	Reward: [-1. -1. -2.]
# Episode: 567	Reward: [-1. -2. -2.]
# Episode: 568	Reward: [-1. -1. -1.]
# Episode: 569	Reward: [-1. -2. -3.]
# Episode: 570	Reward: [-1. -2. -2.]
# Episode: 571	Reward: [-1. -1. -2.]
# Episode: 572	Reward: [-1. -2. -2.]
# Episode: 573	Reward: [-1. -1. -2.]
# Episode: 574	Reward: [-1. -2. -2.]
# Episode: 575	Reward: [-1. -1. -1.]
# Episode: 576	Reward: [-1. -1. -1.]
# Episode: 577	Reward: [-1. -1. -1.]
# Episode: 578	Reward: [-1. -1. -1.]
# Episode: 579	Reward: [-1. -2. -3.]
# Episode: 580	Reward: [-1. -1. -1.]
# Episode: 581	Reward: [-1. -2. -2.]
# Episode: 582	Reward: [-1. -1. -1.]
# Episode: 583	Reward: [-1. -1. -1.]
# Episode: 584	Reward: [-1. -1. -1.]
# Episode: 585	Reward: [-1. -1. -1.]
# Episode: 586	Reward: [-1. -2. -2.]
# Episode: 587	Reward: [-1. -2. -2.]
# Episode: 588	Reward: [-1. -1. -2.]
# Episode: 589	Reward: [-1. -2. -2.]
# Episode: 590	Reward: [-1. -1. -1.]
# Episode: 591	Reward: [-1. -1. -1.]
# Episode: 592	Reward: [-1. -2. -2.]
# Episode: 593	Reward: [-1. -1. -1.]
# Episode: 594	Reward: [-1. -2. -3.]
# Episode: 595	Reward: [-1. -1. -1.]
# Episode: 596	Reward: [-1. -2. -2.]
# Episode: 597	Reward: [-1. -1. -1.]
# Episode: 598	Reward: [-1. -2. -3.]
# Episode: 599	Reward: [-1. -1. -1.]
# Episode: 600	Reward: [-1. -2. -2.]
# Episode: 601	Reward: [-1. -1. -1.]
# Episode: 602	Reward: [-1. -1. -1.]
# Episode: 603	Reward: [-1. -2. -3.]
# Episode: 604	Reward: [-1. -1. -1.]
# Episode: 605	Reward: [-1. -1. -1.]
# Episode: 606	Reward: [-1. -1. -1.]
# Episode: 607	Reward: [-1. -2. -3.]
# Episode: 608	Reward: [-1. -1. -1.]
# Episode: 609	Reward: [-1. -1. -1.]
# Episode: 610	Reward: [-1. -1. -1.]
# Episode: 611	Reward: [-1. -1. -1.]
# Episode: 612	Reward: [-1. -2. -2.]
# Episode: 613	Reward: [-1. -1. -2.]
# Episode: 614	Reward: [-1. -1. -1.]
# Episode: 615	Reward: [-1. -1. -1.]
# Episode: 616	Reward: [-1. -2. -3.]
# Episode: 617	Reward: [-1. -1. -1.]
# Episode: 618	Reward: [-1. -1. -1.]
# Episode: 619	Reward: [-1. -2. -2.]
# Episode: 620	Reward: [-1. -1. -1.]
# Episode: 621	Reward: [-1. -2. -3.]
# Episode: 622	Reward: [-1. -1. -1.]
# Episode: 623	Reward: [-1. -1. -1.]
# Episode: 624	Reward: [-1. -1. -1.]
# Episode: 625	Reward: [-1. -2. -2.]
# Episode: 626	Reward: [-1. -1. -1.]
# Episode: 627	Reward: [-1. -1. -1.]
# Episode: 628	Reward: [-1. -2. -2.]
# Episode: 629	Reward: [-1. -1. -1.]
# Episode: 630	Reward: [-1. -1. -1.]
# Episode: 631	Reward: [-1. -2. -3.]
# Episode: 632	Reward: [-1. -1. -1.]
# Episode: 633	Reward: [-1. -2. -2.]
# Episode: 634	Reward: [-1. -1. -2.]
# Episode: 635	Reward: [-1. -1. -1.]
# Episode: 636	Reward: [-1. -1. -1.]
# Episode: 637	Reward: [-1. -2. -3.]
# Episode: 638	Reward: [-1. -2. -3.]
# Episode: 639	Reward: [-1. -2. -2.]
# Episode: 640	Reward: [-1. -1. -1.]
# Episode: 641	Reward: [-1. -1. -1.]
# Episode: 642	Reward: [-1. -1. -1.]
# Episode: 643	Reward: [-1. -2. -2.]
# Episode: 644	Reward: [-1. -2. -2.]
# Episode: 645	Reward: [-1. -1. -1.]
# Episode: 646	Reward: [-1. -1. -1.]
# Episode: 647	Reward: [-1. -2. -2.]
# Episode: 648	Reward: [-1. -2. -2.]
# Episode: 649	Reward: [-1. -2. -3.]
# Episode: 650	Reward: [-1. -1. -2.]
# Episode: 651	Reward: [-1. -1. -2.]
# Episode: 652	Reward: [-1. -1. -1.]
# Episode: 653	Reward: [-1. -1. -2.]
# Episode: 654	Reward: [-1. -1. -1.]
# Episode: 655	Reward: [-1. -1. -1.]
# Episode: 656	Reward: [-1. -1. -1.]
# Episode: 657	Reward: [-1. -1. -2.]
# Episode: 658	Reward: [-1. -1. -1.]
# Episode: 659	Reward: [-1. -1. -1.]
# Episode: 660	Reward: [-1. -2. -2.]
# Episode: 661	Reward: [-1. -1. -1.]
# Episode: 662	Reward: [-1. -1. -2.]
# Episode: 663	Reward: [-1. -1. -1.]
# Episode: 664	Reward: [-1. -1. -2.]
# Episode: 665	Reward: [-1. -2. -3.]
# Episode: 666	Reward: [-1. -2. -2.]
# Episode: 667	Reward: [-1. -2. -2.]
# Episode: 668	Reward: [-1. -1. -1.]
# Episode: 669	Reward: [-1. -2. -2.]
# Episode: 670	Reward: [-1. -1. -1.]
# Episode: 671	Reward: [-1. -2. -3.]
# Episode: 672	Reward: [-1. -2. -3.]
# Episode: 673	Reward: [-1. -1. -1.]
# Episode: 674	Reward: [-1. -1. -1.]
# Episode: 675	Reward: [-1. -1. -1.]
# Episode: 676	Reward: [-1. -1. -1.]
# Episode: 677	Reward: [-1. -1. -1.]
# Episode: 678	Reward: [-1. -1. -1.]
# Episode: 679	Reward: [-1. -1. -1.]
# Episode: 680	Reward: [-1. -1. -1.]
# Episode: 681	Reward: [-1. -2. -3.]
# Episode: 682	Reward: [-1. -1. -2.]
# Episode: 683	Reward: [-1. -1. -1.]
# Episode: 684	Reward: [-1. -1. -2.]
# Episode: 685	Reward: [-1. -2. -3.]
# Episode: 686	Reward: [-1. -2. -3.]
# Episode: 687	Reward: [-1. -1. -1.]
# Episode: 688	Reward: [-1. -1. -1.]
# Episode: 689	Reward: [-1. -1. -1.]
# Episode: 690	Reward: [-1. -1. -2.]
# Episode: 691	Reward: [-1. -1. -1.]
# Episode: 692	Reward: [-1. -2. -2.]
# Episode: 693	Reward: [-1. -2. -2.]
# Episode: 694	Reward: [-1. -1. -1.]
# Episode: 695	Reward: [-1. -2. -2.]
# Episode: 696	Reward: [-1. -1. -2.]
# Episode: 697	Reward: [-1. -2. -2.]
# Episode: 698	Reward: [-1. -2. -2.]
# Episode: 699	Reward: [-1. -2. -2.]
# Episode: 700	Reward: [-1. -2. -3.]
# Episode: 701	Reward: [-1. -1. -1.]
# Episode: 702	Reward: [-1. -2. -2.]
# Episode: 703	Reward: [-1. -1. -1.]
# Episode: 704	Reward: [-1. -1. -1.]
# Episode: 705	Reward: [-1. -1. -1.]
# Episode: 706	Reward: [-1. -1. -2.]
# Episode: 707	Reward: [-1. -2. -2.]
# Episode: 708	Reward: [-1. -1. -2.]
# Episode: 709	Reward: [-1. -2. -3.]
# Episode: 710	Reward: [-1. -1. -1.]
# Episode: 711	Reward: [-1. -1. -1.]
# Episode: 712	Reward: [-1. -2. -3.]
# Episode: 713	Reward: [-1. -1. -1.]
# Episode: 714	Reward: [-1. -2. -2.]
# Episode: 715	Reward: [-1. -1. -1.]
# Episode: 716	Reward: [-1. -2. -2.]
# Episode: 717	Reward: [-1. -1. -1.]
# Episode: 718	Reward: [-1. -1. -1.]
# Episode: 719	Reward: [-1. -1. -1.]
# Episode: 720	Reward: [-1. -1. -1.]
# Episode: 721	Reward: [-1. -1. -1.]
# Episode: 722	Reward: [-1. -2. -2.]
# Episode: 723	Reward: [-1. -2. -2.]
# Episode: 724	Reward: [-1. -2. -2.]
# Episode: 725	Reward: [-1. -1. -1.]
# Episode: 726	Reward: [-1. -1. -2.]
# Episode: 727	Reward: [-1. -1. -1.]
# Episode: 728	Reward: [-1. -1. -2.]
# Episode: 729	Reward: [-1. -1. -1.]
# Episode: 730	Reward: [-1. -1. -1.]
# Episode: 731	Reward: [-1. -1. -1.]
# Episode: 732	Reward: [-1. -1. -1.]
# Episode: 733	Reward: [-1. -1. -1.]
# Episode: 734	Reward: [-1. -2. -2.]
# Episode: 735	Reward: [-1. -2. -2.]
# Episode: 736	Reward: [-1. -1. -2.]
# Episode: 737	Reward: [-1. -1. -2.]
# Episode: 738	Reward: [-1. -1. -1.]
# Episode: 739	Reward: [-1. -1. -2.]
# Episode: 740	Reward: [-1. -2. -2.]
# Episode: 741	Reward: [-1. -2. -3.]
# Episode: 742	Reward: [-1. -1. -2.]
# Episode: 743	Reward: [-1. -1. -1.]
# Episode: 744	Reward: [-1. -2. -3.]
# Episode: 745	Reward: [-1. -2. -2.]
# Episode: 746	Reward: [-1. -1. -1.]
# Episode: 747	Reward: [-1. -1. -1.]
# Episode: 748	Reward: [-1. -1. -2.]
# Episode: 749	Reward: [-1. -1. -1.]
# Episode: 750	Reward: [-1. -1. -1.]
# Episode: 751	Reward: [-1. -1. -2.]
# Episode: 752	Reward: [-1. -1. -1.]
# Episode: 753	Reward: [-1. -2. -2.]
# Episode: 754	Reward: [-1. -1. -1.]
# Episode: 755	Reward: [-1. -1. -1.]
# Episode: 756	Reward: [-1. -1. -1.]
# Episode: 757	Reward: [-1. -1. -1.]
# Episode: 758	Reward: [-1. -1. -1.]
# Episode: 759	Reward: [-1. -1. -2.]
# Episode: 760	Reward: [-1. -2. -2.]
# Episode: 761	Reward: [-1. -1. -1.]
# Episode: 762	Reward: [-1. -2. -3.]
# Episode: 763	Reward: [-1. -2. -3.]
# Episode: 764	Reward: [-1. -1. -1.]
# Episode: 765	Reward: [-1. -2. -2.]
# Episode: 766	Reward: [-1. -1. -1.]
# Episode: 767	Reward: [-1. -1. -2.]
# Episode: 768	Reward: [-1. -1. -1.]
# Episode: 769	Reward: [-1. -1. -1.]
# Episode: 770	Reward: [-1. -2. -2.]
# Episode: 771	Reward: [-1. -1. -1.]
# Episode: 772	Reward: [-1. -1. -1.]
# Episode: 773	Reward: [-1. -2. -2.]
# Episode: 774	Reward: [-1. -1. -2.]
# Episode: 775	Reward: [-1. -2. -2.]
# Episode: 776	Reward: [-1. -1. -1.]
# Episode: 777	Reward: [-1. -1. -1.]
# Episode: 778	Reward: [-1. -2. -2.]
# Episode: 779	Reward: [-1. -1. -1.]
# Episode: 780	Reward: [-1. -1. -2.]
# Episode: 781	Reward: [-1. -1. -1.]
# Episode: 782	Reward: [-1. -1. -1.]
# Episode: 783	Reward: [-1. -2. -2.]
# Episode: 784	Reward: [-1. -1. -1.]
# Episode: 785	Reward: [-1. -2. -3.]
# Episode: 786	Reward: [-1. -1. -1.]
# Episode: 787	Reward: [-1. -1. -1.]
# Episode: 788	Reward: [-1. -2. -3.]
# Episode: 789	Reward: [-1. -1. -1.]
# Episode: 790	Reward: [-1. -1. -2.]
# Episode: 791	Reward: [-1. -1. -1.]
# Episode: 792	Reward: [-1. -1. -1.]
# Episode: 793	Reward: [-1. -2. -3.]
# Episode: 794	Reward: [-1. -1. -1.]
# Episode: 795	Reward: [-1. -2. -2.]
# Episode: 796	Reward: [-1. -1. -1.]
# Episode: 797	Reward: [-1. -1. -1.]
# Episode: 798	Reward: [-1. -2. -2.]
# Episode: 799	Reward: [-1. -1. -2.]
# Episode: 800	Reward: [-1. -2. -2.]
# Episode: 801	Reward: [-1. -1. -1.]
# Episode: 802	Reward: [-1. -1. -1.]
# Episode: 803	Reward: [-1. -1. -1.]
# Episode: 804	Reward: [-1. -2. -3.]
# Episode: 805	Reward: [-1. -2. -2.]
# Episode: 806	Reward: [-1. -1. -1.]
# Episode: 807	Reward: [-1. -1. -1.]
# Episode: 808	Reward: [-1. -2. -2.]
# Episode: 809	Reward: [-1. -1. -2.]
# Episode: 810	Reward: [-1. -1. -1.]
# Episode: 811	Reward: [-1. -2. -2.]
# Episode: 812	Reward: [-1. -1. -1.]
# Episode: 813	Reward: [-1. -1. -2.]
# Episode: 814	Reward: [-1. -2. -2.]
# Episode: 815	Reward: [-1. -1. -1.]
# Episode: 816	Reward: [-1. -1. -1.]
# Episode: 817	Reward: [-1. -2. -2.]
# Episode: 818	Reward: [-1. -2. -2.]
# Episode: 819	Reward: [-1. -1. -1.]
# Episode: 820	Reward: [-1. -1. -1.]
# Episode: 821	Reward: [-1. -1. -1.]
# Episode: 822	Reward: [-1. -1. -1.]
# Episode: 823	Reward: [-1. -1. -2.]
# Episode: 824	Reward: [-1. -2. -2.]
# Episode: 825	Reward: [-1. -1. -1.]
# Episode: 826	Reward: [-1. -2. -3.]
# Episode: 827	Reward: [-1. -1. -1.]
# Episode: 828	Reward: [-1. -1. -1.]
# Episode: 829	Reward: [-1. -1. -1.]
# Episode: 830	Reward: [-1. -2. -2.]
# Episode: 831	Reward: [-1. -1. -1.]
# Episode: 832	Reward: [-1. -1. -1.]
# Episode: 833	Reward: [-1. -1. -1.]
# Episode: 834	Reward: [-1. -1. -1.]
# Episode: 835	Reward: [-1. -1. -1.]
# Episode: 836	Reward: [-1. -1. -2.]
# Episode: 837	Reward: [-1. -1. -1.]
# Episode: 838	Reward: [-1. -1. -2.]
# Episode: 839	Reward: [-1. -2. -3.]
# Episode: 840	Reward: [-1. -1. -1.]
# Episode: 841	Reward: [-1. -1. -1.]
# Episode: 842	Reward: [-1. -1. -2.]
# Episode: 843	Reward: [-1. -1. -1.]
# Episode: 844	Reward: [-1. -1. -1.]
# Episode: 845	Reward: [-1. -1. -1.]
# Episode: 846	Reward: [-1. -2. -2.]
# Episode: 847	Reward: [-1. -1. -2.]
# Episode: 848	Reward: [-1. -1. -2.]
# Episode: 849	Reward: [-1. -1. -2.]
# Episode: 850	Reward: [-1. -1. -1.]
# Episode: 851	Reward: [-1. -1. -1.]
# Episode: 852	Reward: [-1. -1. -1.]
# Episode: 853	Reward: [-1. -1. -2.]
# Episode: 854	Reward: [-1. -1. -1.]
# Episode: 855	Reward: [-1. -2. -2.]
# Episode: 856	Reward: [-1. -1. -2.]
# Episode: 857	Reward: [-1. -2. -2.]
# Episode: 858	Reward: [-1. -2. -2.]
# Episode: 859	Reward: [-1. -1. -2.]
# Episode: 860	Reward: [-1. -1. -1.]
# Episode: 861	Reward: [-1. -1. -1.]
# Episode: 862	Reward: [-1. -1. -1.]
# Episode: 863	Reward: [-1. -1. -1.]
# Episode: 864	Reward: [-1. -2. -3.]
# Episode: 865	Reward: [-1. -1. -2.]
# Episode: 866	Reward: [-1. -1. -1.]
# Episode: 867	Reward: [-1. -1. -1.]
# Episode: 868	Reward: [-1. -1. -1.]
# Episode: 869	Reward: [-1. -1. -1.]
# Episode: 870	Reward: [-1. -2. -2.]
# Episode: 871	Reward: [-1. -2. -2.]
# Episode: 872	Reward: [-1. -1. -2.]
# Episode: 873	Reward: [-1. -1. -1.]
# Episode: 874	Reward: [-1. -2. -2.]
# Episode: 875	Reward: [-1. -1. -1.]
# Episode: 876	Reward: [-1. -2. -2.]
# Episode: 877	Reward: [-1. -1. -1.]
# Episode: 878	Reward: [-1. -1. -1.]
# Episode: 879	Reward: [-1. -1. -1.]
# Episode: 880	Reward: [-1. -1. -1.]
# Episode: 881	Reward: [-1. -1. -1.]
# Episode: 882	Reward: [-1. -1. -1.]
# Episode: 883	Reward: [-1. -2. -2.]
# Episode: 884	Reward: [-1. -2. -2.]
# Episode: 885	Reward: [-1. -1. -1.]
# Episode: 886	Reward: [-1. -1. -1.]
# Episode: 887	Reward: [-1. -1. -1.]
# Episode: 888	Reward: [-1. -2. -2.]
# Episode: 889	Reward: [-1. -1. -2.]
# Episode: 890	Reward: [-1. -1. -1.]
# Episode: 891	Reward: [-1. -1. -1.]
# Episode: 892	Reward: [-1. -2. -2.]
# Episode: 893	Reward: [-1. -2. -2.]
# Episode: 894	Reward: [-1. -1. -1.]
# Episode: 895	Reward: [-1. -2. -2.]
# Episode: 896	Reward: [-1. -1. -1.]
# Episode: 897	Reward: [-1. -1. -1.]
# Episode: 898	Reward: [-1. -1. -1.]
# Episode: 899	Reward: [-1. -2. -2.]
# Episode: 900	Reward: [-1. -1. -1.]
# Episode: 901	Reward: [-1. -2. -2.]
# Episode: 902	Reward: [-1. -1. -1.]
# Episode: 903	Reward: [-1. -1. -1.]
# Episode: 904	Reward: [-1. -1. -2.]
# Episode: 905	Reward: [-1. -1. -1.]
# Episode: 906	Reward: [-1. -1. -2.]
# Episode: 907	Reward: [-1. -2. -2.]
# Episode: 908	Reward: [-1. -1. -1.]
# Episode: 909	Reward: [-1. -1. -1.]
# Episode: 910	Reward: [-1. -1. -1.]
# Episode: 911	Reward: [-1. -2. -2.]
# Episode: 912	Reward: [-1. -2. -2.]
# Episode: 913	Reward: [-1. -1. -1.]
# Episode: 914	Reward: [-1. -1. -2.]
# Episode: 915	Reward: [-1. -2. -2.]
# Episode: 916	Reward: [-1. -1. -1.]
# Episode: 917	Reward: [-1. -2. -2.]
# Episode: 918	Reward: [-1. -2. -2.]
# Episode: 919	Reward: [-1. -1. -1.]
# Episode: 920	Reward: [-1. -2. -2.]
# Episode: 921	Reward: [-1. -2. -2.]
# Episode: 922	Reward: [-1. -1. -1.]
# Episode: 923	Reward: [-1. -1. -1.]
# Episode: 924	Reward: [-1. -2. -3.]
# Episode: 925	Reward: [-1. -1. -1.]
# Episode: 926	Reward: [-1. -1. -1.]
# Episode: 927	Reward: [-1. -2. -2.]
# Episode: 928	Reward: [-1. -1. -1.]
# Episode: 929	Reward: [-1. -2. -2.]
# Episode: 930	Reward: [-1. -2. -2.]
# Episode: 931	Reward: [-1. -1. -1.]
# Episode: 932	Reward: [-1. -1. -2.]
# Episode: 933	Reward: [-1. -2. -2.]
# Episode: 934	Reward: [-1. -1. -1.]
# Episode: 935	Reward: [-1. -2. -2.]
# Episode: 936	Reward: [-1. -2. -2.]
# Episode: 937	Reward: [-1. -1. -1.]
# Episode: 938	Reward: [-1. -2. -2.]
# Episode: 939	Reward: [-1. -2. -2.]
# Episode: 940	Reward: [-1. -1. -1.]
# Episode: 941	Reward: [-1. -2. -3.]
# Episode: 942	Reward: [-1. -2. -2.]
# Episode: 943	Reward: [-1. -1. -2.]
# Episode: 944	Reward: [-1. -1. -1.]
# Episode: 945	Reward: [-1. -2. -3.]
# Episode: 946	Reward: [-1. -1. -2.]
# Episode: 947	Reward: [-1. -1. -1.]
# Episode: 948	Reward: [-1. -1. -1.]
# Episode: 949	Reward: [-1. -1. -1.]
# Episode: 950	Reward: [-1. -1. -2.]
# Episode: 951	Reward: [-1. -1. -1.]
# Episode: 952	Reward: [-1. -2. -2.]
# Episode: 953	Reward: [-1. -1. -1.]
# Episode: 954	Reward: [-1. -2. -3.]
# Episode: 955	Reward: [-1. -1. -1.]
# Episode: 956	Reward: [-1. -1. -1.]
# Episode: 957	Reward: [-1. -2. -2.]
# Episode: 958	Reward: [-1. -1. -1.]
# Episode: 959	Reward: [-1. -1. -1.]
# Episode: 960	Reward: [-1. -1. -1.]
# Episode: 961	Reward: [-1. -2. -2.]
# Episode: 962	Reward: [-1. -2. -2.]
# Episode: 963	Reward: [-1. -1. -2.]
# Episode: 964	Reward: [-1. -2. -3.]
# Episode: 965	Reward: [-1. -1. -1.]
# Episode: 966	Reward: [-1. -1. -1.]
# Episode: 967	Reward: [-1. -2. -3.]
# Episode: 968	Reward: [-1. -1. -1.]
# Episode: 969	Reward: [-1. -1. -1.]
# Episode: 970	Reward: [-1. -1. -2.]
# Episode: 971	Reward: [-1. -2. -2.]
# Episode: 972	Reward: [-1. -1. -1.]
# Episode: 973	Reward: [-1. -1. -1.]
# Episode: 974	Reward: [-1. -1. -1.]
# Episode: 975	Reward: [-1. -1. -1.]
# Episode: 976	Reward: [-1. -1. -1.]
# Episode: 977	Reward: [-1. -1. -1.]
# Episode: 978	Reward: [-1. -1. -2.]
# Episode: 979	Reward: [-1. -2. -2.]
# Episode: 980	Reward: [-1. -1. -1.]
# Episode: 981	Reward: [-1. -1. -2.]
# Episode: 982	Reward: [-1. -1. -1.]
# Episode: 983	Reward: [-1. -1. -1.]
# Episode: 984	Reward: [-1. -2. -2.]
# Episode: 985	Reward: [-1. -1. -1.]
# Episode: 986	Reward: [-1. -1. -1.]
# Episode: 987	Reward: [-1. -1. -1.]
# Episode: 988	Reward: [-1. -1. -1.]
# Episode: 989	Reward: [-1. -1. -1.]
# Episode: 990	Reward: [-1. -2. -2.]
# Episode: 991	Reward: [-1. -1. -1.]
# Episode: 992	Reward: [-1. -2. -2.]
# Episode: 993	Reward: [-1. -1. -2.]
# Episode: 994	Reward: [-1. -1. -1.]
# Episode: 995	Reward: [-1. -1. -1.]
# Episode: 996	Reward: [-1. -1. -2.]
# Episode: 997	Reward: [-1. -1. -1.]
# Episode: 998	Reward: [-1. -2. -2.]
# Episode: 999	Reward: [-1. -2. -3.]
# Episode: 1000	Reward: [-1. -2. -3.]

# %%
ppo = PPO(state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip)

running_reward = 0
rewards = []
for ep in range(1, n_episodes+1):
    state = np.array([0.0])
    for t in range(max_timesteps):
        # Running policy_old:
        action = ppo.policy_old(state)
        reward = env.step(action)[0] + env.step(action)[1] +env.step(action)[2]
        state_n = env.get_state()
        done = env.is_terminal()
        # Saving state and reward:
        ppo.policy_old.states.append(state)
        ppo.policy_old.rewards.append(reward)
        state = np.array([state_n])
        running_reward +=reward 
        if done:
            # save model
            torch.save(ppo.policy.state_dict(), directory+filename)
            rewards.append(running_reward)
            break

    print('Episode: {}\tReward: {}'.format(ep, int(running_reward)))
    running_reward = 0

plt.plot(np.arange(len(rewards)), rewards, label = 'reward1')
plt.ylabel('Total Reward')
plt.xlabel('Episode')
plt.savefig('mountaincar_base',bbox_inches='tight',facecolor="#FFFFFF")
plt.show()
# Out:
#  166	Reward: -1
# Episode: 167	Reward: -1
# Episode: 168	Reward: -2
# Episode: 169	Reward: -2
# Episode: 170	Reward: -2
# Episode: 171	Reward: -2
# Episode: 172	Reward: -2
# Episode: 173	Reward: -2
# Episode: 174	Reward: -2
# Episode: 175	Reward: -1
# Episode: 176	Reward: -2
# Episode: 177	Reward: -2
